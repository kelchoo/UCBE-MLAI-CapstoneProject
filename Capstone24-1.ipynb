# %% [markdown]
# # Capstone Project 24.1:Capstone Project
# ## Project Title: Building an Machine Learning solution on Shopify's App Store in the aim of maximizing revenue, lower cost and reduce customer churn (stimulate and accelerate the Shopify Business Model)
#
# ![image.png](attachment:d3ceaa6e-b129-413f-9bc0-381b01091f1e.png)
#
# **Overview**: In this module, you get to do the actual ‘number crunching’ for your capstone project. Spend your time in this module creating and training your models, as well as creating visualizations to make sense of your findings. You will have time in Module 24 to clean the code and make your work presentable for technical and non-technical audiences; for now, you will do the ‘heavy lifting’ of finding the answer to your research question.
#
# #### -	Program learning outcomes addressed this module:
# #### -	Apply real-world tools to model and analyze real-world data
# #### -	Communicate foundational concepts about AI/ML
# #### -	Draw useful conclusions from real-world data
# #### -	Identify the best ML model to solve a problem
# #### -	Implement the ML/Data Science Life Cycle
#
# Explore your data sources, test a few of the techniques, and come up with a solution or answer to your research question. The answer does not have to be ‘pretty’ or easily understood at the moment.
# In Module 24, you will spend time fine-tuning your answer and packaging it for non-technical audiences. For this module, you are only responsible for the number crunching.

# %% [markdown]
# ### Getting Started
#
# •	The research question you intend to answer (one sentence, if possible):
#
# •	As a Shopify Marketing Corporate Executive: how do I get a recommendation of the top apps  which I should focus my marketing expenses when using the monthly reports provided (as shown in the data source as extracted from Shopify’s website in the link provided below)  based on the various features and attributes of each app currently available on my store at the start of a given month (assuming the files have been provided in the point below from Shopify’s internal database to the marketing team) so I can maximize revenues for each month ?
# •Expected data source(s) :
# https://www.kaggle.com/datasets/usernam3/shopify-app-store?select=reviews.csv
#
# 1. apps.csv
# 2. apps_categories.csv
# 3. categories.csv
# 4. key_benefits.csv
# 5. pricing_plan_features.csv
# 6. reviews.csv
#
# #### The above data sources contains the following key attributes about the apps currently offered on Shopify website for its merchants to download, purchase and use for various purposes that include increasing sales, simplify processes for completing the sales and invoicing processes or even promoting its website and measure revenue and forecasts inventory and sales growth.
# -	Data includes:  App Counts, App Store review, pricing hints, descriptions, review counts, ratings, the various pricing plans offered for app developers
# #### •The techniques you expect to use in my analysis:
#
# #### 2.PCA (this can be used as dimensionality-reduction technique to reduce the size of large datasets related to apps feedback by rating and reviews and by transforming a large set of variables into a smaller one that retains most of the information present in the large set) are techniques that I would be using to perform the following:
#
# #### 3.Identify the top categories of apps based on review_counts, ratings (0-5)
#
# #### 4.Cluster them based on pricing plans and then rank them accordingly to show the categories of high pricing apps (based on on time, install, features of the apps)
#
# #### 5.Use deep learning techniques to find similar Shopify apps within a category or across categories that have similar App Descriptions to further add features and do data preprocessing to correct the classification of apps into broader categories.
#
# ### •	The expected results
#
# #### With the techniques identified and the data provided from the Appstore database within Spotify corporate IT environment as shown in the link above on the data sets,  I should be able to the following business questions/areas:
# 1.	Review the top apps in each of the top 3 categories
#
# 2.	Identify the pricing used by these apps
#
# 3.	Understand what people in reviews are complaining about. Poor quality app might be an opportunity for the new app that solves the same problem better. Focus marketing spend to help correct these reviews with the app partners especially when the number of ratings and reviews are high.
#
# 4.	Bring a more accurate classification and clustering of apps in broad and similar categories for management to understand the key growth areas.

# %% [markdown]
# ### Step 1: Understanding the Data
#
# To gain a better understanding of the data:
# · Libraries are imported and aliased correctly
# · Appropriate plots for categorical and continuous variables are utilized
# · Demonstrates competency with pandas
# · Demonstrates competency with seaborn
# · Variables are sensible

# %%
import pandas as pd
#importing the libraries 
import numpy as np # linear algebra
import pandas as pd # data processing with CSV 
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
import scipy.stats as stats
import pylab
import warnings
import seaborn as sns

warnings.filterwarnings("ignore")
# %matplotlib inline
warnings.filterwarnings('ignore')

# From Scikit Learn
from sklearn import preprocessing, decomposition, tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, confusion_matrix, classification_report
from astropy.table import Table, Column
# Set DEBUG = True to produce debug results
DEBUG = False


from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
import numpy as np
import pandas as pd 
import os
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn import metrics
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix,r2_score
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
import warnings
from imblearn.over_sampling import SMOTE
warnings.filterwarnings('ignore')


from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import BernoulliNB 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

#Metrics Phase
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score

#Visualization Phase

import matplotlib.pylab as pylab
# %matplotlib inline
pd.set_option('display.max_columns', 500)

sns.set_style('white')
pylab.rcParams['figure.figsize'] = 12,8
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix,r2_score
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier

import plotly
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Step 2: Read in the Data
#
# Use pandas to read in the datasets` and assign to a meaningful variable name.
# explain logic standpoints
#
# 1.pandas - important library sets to acquire the data for further analysis and organize the data.
#
# 2.storyline - what is the data about.
#
# 3.purpose for reading the data to do the following:

# %%
pwd
# Out:
# '/Users/kelvinchoo/UCBE/Capstone'

# %%
# source
apps = pd.read_csv('data/apps.csv')
categories = pd.read_csv('data/categories.csv')
reviews = pd.read_csv('data/reviews.csv')
pricing_plans=pd.read_csv('data/pricing_plans.csv')
pricing_plan_features=pd.read_csv('data/pricing_plan_features.csv')
key_benefits=pd.read_csv('data/key_benefits.csv')
apps_categories=pd.read_csv('data/apps_categories.csv')

# %%
apps.head()
# Out:
#                                      id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7
# 1  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 2  cd229797-5798-4465-a313-2e27ce44e01d
# 3  6e07c6c8-8617-43d2-9a88-bafcbfe82f7f
# 4  8ff58c99-e85c-44cd-ad13-7df88fbab704
#
#                                            url  \
# 0  https://apps.shopify.com/jewelexchange_feed
# 1           https://apps.shopify.com/cocon-app
# 2            https://apps.shopify.com/quantify
# 3        https://apps.shopify.com/orderlyprint
# 4             https://apps.shopify.com/smsbump
#
#                             title           developer  \
# 0  JewelExchange Product Feed API     Avalon Solution
# 1           COCON ‑ Emails, Popup            COCON SA
# 2                        Quantify  Akuna Technologies
# 3                    OrderlyPrint    FORSBERG+two ApS
# 4  SMSBump SMS Marketing by Yotpo         SMSBump Ltd
#
#                                       developer_link  \
# ...

# %%
apps = apps.rename(columns={'id': 'app_id'})

# %%
apps.head()
# Out:
#                                  app_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7
# 1  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 2  cd229797-5798-4465-a313-2e27ce44e01d
# 3  6e07c6c8-8617-43d2-9a88-bafcbfe82f7f
# 4  8ff58c99-e85c-44cd-ad13-7df88fbab704
#
#                                            url  \
# 0  https://apps.shopify.com/jewelexchange_feed
# 1           https://apps.shopify.com/cocon-app
# 2            https://apps.shopify.com/quantify
# 3        https://apps.shopify.com/orderlyprint
# 4             https://apps.shopify.com/smsbump
#
#                             title           developer  \
# 0  JewelExchange Product Feed API     Avalon Solution
# 1           COCON ‑ Emails, Popup            COCON SA
# 2                        Quantify  Akuna Technologies
# 3                    OrderlyPrint    FORSBERG+two ApS
# 4  SMSBump SMS Marketing by Yotpo         SMSBump Ltd
#
#                                       developer_link  \
# ...

# %%
apps.shape
# Out:
# (7341, 13)

# %%
# find the percentage of missing values
missing_values = apps.isna().mean().round(4) * 100
print(missing_values)
# Out:
# app_id             0.0
# url                0.0
# title              0.0
# developer          0.0
# developer_link     0.0
# icon               0.0
# rating             0.0
# reviews_count      0.0
# description_raw    0.0
# description        0.0
# tagline            0.0
# pricing_hint       0.0
# lastmod            0.0
# dtype: float64

# %% [markdown]
# #### Step 2.1 creating joins with pricing and categories and factorize the data for easy identification and joining the data.

# %%
apps_categories.head()
# Out:
#                                  app_id                       category_id
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7  c769c2bd15500dd906102d9be97fdceb
# 1  afbe525f-d512-4951-8edc-582df3ce6aa7  3be6496a88459c633342f1ec6e2be5f4
# 2  9594ccfa-9ef9-42a2-823c-e270489bcb88  c3f9db73c29bc33607778f9935c3c4dc
# 3  9594ccfa-9ef9-42a2-823c-e270489bcb88  c769c2bd15500dd906102d9be97fdceb
# 4  9594ccfa-9ef9-42a2-823c-e270489bcb88  8a496e4dcb443b1c529e75d7ec2888df

# %%
categories.head()
# Out:
#                                  id             title
# 0  c769c2bd15500dd906102d9be97fdceb         Marketing
# 1  3be6496a88459c633342f1ec6e2be5f4  Store management
# 2  c3f9db73c29bc33607778f9935c3c4dc      Store design
# 3  8a496e4dcb443b1c529e75d7ec2888df        Conversion
# 4  06c707e64951fc6bb9ba7e6e26d252eb     Merchandising

# %%
apps_with_categories = pd.merge(apps_categories, categories, how='right', left_on='category_id', right_on='id')

# %%
apps_with_categories.head()
# Out:
#                                  app_id                       category_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7  c769c2bd15500dd906102d9be97fdceb
# 1  9594ccfa-9ef9-42a2-823c-e270489bcb88  c769c2bd15500dd906102d9be97fdceb
# 2  8ff58c99-e85c-44cd-ad13-7df88fbab704  c769c2bd15500dd906102d9be97fdceb
# 3  0bf899ad-728f-4695-8dd5-cd510a27a4b2  c769c2bd15500dd906102d9be97fdceb
# 4  477982de-97d2-4454-a552-b42bd9b5ccbe  c769c2bd15500dd906102d9be97fdceb
#
#                                  id      title
# 0  c769c2bd15500dd906102d9be97fdceb  Marketing
# 1  c769c2bd15500dd906102d9be97fdceb  Marketing
# 2  c769c2bd15500dd906102d9be97fdceb  Marketing
# 3  c769c2bd15500dd906102d9be97fdceb  Marketing
# 4  c769c2bd15500dd906102d9be97fdceb  Marketing

# %%
## clean up additional column column after merge
apps_with_categories = apps_with_categories.drop('id', axis=1)

# %%
apps_with_categories.head()
# Out:
#                                  app_id                       category_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7  c769c2bd15500dd906102d9be97fdceb
# 1  9594ccfa-9ef9-42a2-823c-e270489bcb88  c769c2bd15500dd906102d9be97fdceb
# 2  8ff58c99-e85c-44cd-ad13-7df88fbab704  c769c2bd15500dd906102d9be97fdceb
# 3  0bf899ad-728f-4695-8dd5-cd510a27a4b2  c769c2bd15500dd906102d9be97fdceb
# 4  477982de-97d2-4454-a552-b42bd9b5ccbe  c769c2bd15500dd906102d9be97fdceb
#
#        title
# 0  Marketing
# 1  Marketing
# 2  Marketing
# 3  Marketing
# 4  Marketing

# %%
reviews.head()
# Out:
#                                  app_id             author  rating  \
# 0  8ff58c99-e85c-44cd-ad13-7df88fbab704  Wild Love Apparel       5
# 1  8ff58c99-e85c-44cd-ad13-7df88fbab704       MinnieRoseCo       5
# 2  8ff58c99-e85c-44cd-ad13-7df88fbab704       MagBlaze.com       5
# 3  8ff58c99-e85c-44cd-ad13-7df88fbab704               moré       5
# 4  8ff58c99-e85c-44cd-ad13-7df88fbab704        Cocoa Crush       5
#
#       posted_at                                               body  \
# 0  June 3, 2022  This app has been great for gaining new custom...
# 1  June 2, 2022  I worked with Harry on a validation issue and ...
# 2  June 2, 2022  The system is very useful, it is easy to use a...
# 3  June 2, 2022  Great app. It has very good automation which m...
# 4  June 1, 2022  The team at Yotpo SMSBump Marketing are amazin...
#
#    helpful_count developer_reply developer_reply_posted_at
# 0              0             NaN                       NaN
# ...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640633 entries, 0 to 640632
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   app_id                     640633 non-null  object
#  1   author                     640543 non-null  object
#  2   rating                     640633 non-null  int64
#  3   posted_at                  640633 non-null  object
#  4   body                       640472 non-null  object
#  5   helpful_count              640633 non-null  int64
#  6   developer_reply            131483 non-null  object
#  7   developer_reply_posted_at  131483 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 39.1+ MB

# %%
pricing_plans.head()
# Out:
#                                      id                                app_id  \
# 0  53c9bb6f-bf78-4101-89cf-86c4fe5618e7  afbe525f-d512-4951-8edc-582df3ce6aa7
# 1  5db4ab6c-c3b6-43af-8b47-e439b376ff80  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 2  17e8e6f9-26ee-41d3-b0c0-43895d59097d  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 3  bbb6da74-9eb8-493a-94d8-e780b1e0eeb7  cd229797-5798-4465-a313-2e27ce44e01d
# 4  3eb15591-bf5a-4c01-9fe4-d382058099e1  6e07c6c8-8617-43d2-9a88-bafcbfe82f7f
#
#                 title            price
# 0                 NaN  Free to install
# 1           Free plan  Free to install
# 2  Up to 500 contacts        $18/month
# 3                 NaN      $3.99/month
# 4            Standard        $29/month

# %%
pricing_plans.shape
# Out:
# (12201, 4)

# %%
pricing_plan_features.head()
# Out:
#                                  app_id                       pricing_plan_id  \
# 0  5db4ab6c-c3b6-43af-8b47-e439b376ff80  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 1  5db4ab6c-c3b6-43af-8b47-e439b376ff80  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 2  5db4ab6c-c3b6-43af-8b47-e439b376ff80  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 3  5db4ab6c-c3b6-43af-8b47-e439b376ff80  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 4  5db4ab6c-c3b6-43af-8b47-e439b376ff80  9594ccfa-9ef9-42a2-823c-e270489bcb88
#
#                     feature
# 0             Email capture
# 1  Abandoned carts recovery
# 2          Browsing history
# 3            Analytics data
# 4          Chat support 7/7

# %%
pricing_plan_features.shape
# Out:
# (42107, 3)

# %%
key_benefits.head()
# Out:
#                                  app_id                    title  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7  Easy to Configure & Use
# 1  afbe525f-d512-4951-8edc-582df3ce6aa7   Connect Your Suppliers
# 2  afbe525f-d512-4951-8edc-582df3ce6aa7        Dedicated Support
# 3  9594ccfa-9ef9-42a2-823c-e270489bcb88         Flexible pricing
# 4  9594ccfa-9ef9-42a2-823c-e270489bcb88      Increase your sales
#
#                                          description
# 0  Showcase product data of Jewelry, Watches and ...
# 1  Bridge the gap between your Shopify Store and ...
# 2  Our dedicated customer service team is always ...
# 3  At any time, activate a new feature or deactiv...
# 4  By running automated marketing actions : email...

# %%
key_benefits.shape
# Out:
# (19998, 3)

# %%
categories['category_id'] = categories['title'].factorize()[0]

# %% [markdown]
# ### 2.2 Prepare Dataframes with joined data

# %%
apps_with_categories_and_pricing=[]

# %%
apps_with_categories_and_pricing = pd.merge(apps_with_categories, pricing_plans, how='left', left_on='app_id', right_on='app_id')

# %%
apps_with_categories_and_pricing.head()
# Out:
#                                  app_id                       category_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7  c769c2bd15500dd906102d9be97fdceb
# 1  9594ccfa-9ef9-42a2-823c-e270489bcb88  c769c2bd15500dd906102d9be97fdceb
# 2  9594ccfa-9ef9-42a2-823c-e270489bcb88  c769c2bd15500dd906102d9be97fdceb
# 3  8ff58c99-e85c-44cd-ad13-7df88fbab704  c769c2bd15500dd906102d9be97fdceb
# 4  0bf899ad-728f-4695-8dd5-cd510a27a4b2  c769c2bd15500dd906102d9be97fdceb
#
#      title_x                                    id             title_y  \
# 0  Marketing  53c9bb6f-bf78-4101-89cf-86c4fe5618e7                 NaN
# 1  Marketing  5db4ab6c-c3b6-43af-8b47-e439b376ff80           Free plan
# 2  Marketing  17e8e6f9-26ee-41d3-b0c0-43895d59097d  Up to 500 contacts
# 3  Marketing  0d18e4bf-0fb9-42f4-bac6-881b0c34f08f                 NaN
# 4  Marketing  2d545b11-a598-427f-8724-bcf15f252d2d                Free
#
#              price
# 0  Free to install
# 1  Free to install
# 2        $18/month
# ...

# %%
## rename the columns after merging to the appropriate names for category and price plan
apps_with_categories_and_pricing.rename(columns = {'title_x': 'category', 'title_y': 'price_plan'}, inplace = True)

# %%
apps_with_categories_and_pricing.head()
# Out:
#                                  app_id                       category_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7  c769c2bd15500dd906102d9be97fdceb
# 1  9594ccfa-9ef9-42a2-823c-e270489bcb88  c769c2bd15500dd906102d9be97fdceb
# 2  9594ccfa-9ef9-42a2-823c-e270489bcb88  c769c2bd15500dd906102d9be97fdceb
# 3  8ff58c99-e85c-44cd-ad13-7df88fbab704  c769c2bd15500dd906102d9be97fdceb
# 4  0bf899ad-728f-4695-8dd5-cd510a27a4b2  c769c2bd15500dd906102d9be97fdceb
#
#     category                                    id          price_plan  \
# 0  Marketing  53c9bb6f-bf78-4101-89cf-86c4fe5618e7                 NaN
# 1  Marketing  5db4ab6c-c3b6-43af-8b47-e439b376ff80           Free plan
# 2  Marketing  17e8e6f9-26ee-41d3-b0c0-43895d59097d  Up to 500 contacts
# 3  Marketing  0d18e4bf-0fb9-42f4-bac6-881b0c34f08f                 NaN
# 4  Marketing  2d545b11-a598-427f-8724-bcf15f252d2d                Free
#
#              price
# 0  Free to install
# 1  Free to install
# 2        $18/month
# ...

# %%
apps_and_reviews=[]

# %%
apps_and_reviews = pd.merge(apps, reviews, how='left', left_on='app_id', right_on='app_id')

# %%
# find the percentage of missing values
missing_values = apps_and_reviews.isna().mean().round(4) * 100

# %%
missing_values
# Out:
# app_id                        0.00
# url                           0.00
# title                         0.00
# developer                     0.00
# developer_link                0.00
# icon                          0.00
# rating_x                      0.00
# reviews_count                 0.00
# description_raw               0.00
# description                   0.00
# tagline                       0.00
# pricing_hint                  0.00
# lastmod                       0.00
# author                        0.37
# rating_y                      0.36
# posted_at                     0.36
# body                          0.38
# helpful_count                 0.36
# developer_reply              79.55
# developer_reply_posted_at    79.55
# dtype: float64

# %%
apps_and_reviews.head()
# Out:
#                                  app_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7
# 1  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 2  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 3  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 4  cd229797-5798-4465-a313-2e27ce44e01d
#
#                                            url  \
# 0  https://apps.shopify.com/jewelexchange_feed
# 1           https://apps.shopify.com/cocon-app
# 2           https://apps.shopify.com/cocon-app
# 3           https://apps.shopify.com/cocon-app
# 4            https://apps.shopify.com/quantify
#
#                             title           developer  \
# 0  JewelExchange Product Feed API     Avalon Solution
# 1           COCON ‑ Emails, Popup            COCON SA
# 2           COCON ‑ Emails, Popup            COCON SA
# 3           COCON ‑ Emails, Popup            COCON SA
# 4                        Quantify  Akuna Technologies
#
#                                       developer_link  \
# ...

# %%
apps_and_reviews_with_categories = pd.merge(apps_and_reviews, apps_with_categories, how='left', left_on='app_id', right_on='app_id')

# %%
apps_and_reviews_with_categories.head()
# Out:
#                                  app_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7
# 1  afbe525f-d512-4951-8edc-582df3ce6aa7
# 2  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 3  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 4  9594ccfa-9ef9-42a2-823c-e270489bcb88
#
#                                            url  \
# 0  https://apps.shopify.com/jewelexchange_feed
# 1  https://apps.shopify.com/jewelexchange_feed
# 2           https://apps.shopify.com/cocon-app
# 3           https://apps.shopify.com/cocon-app
# 4           https://apps.shopify.com/cocon-app
#
#                           title_x        developer  \
# 0  JewelExchange Product Feed API  Avalon Solution
# 1  JewelExchange Product Feed API  Avalon Solution
# 2           COCON ‑ Emails, Popup         COCON SA
# 3           COCON ‑ Emails, Popup         COCON SA
# 4           COCON ‑ Emails, Popup         COCON SA
#
#                                       developer_link  \
# 0  https://apps.shopify.com/partners/avalon-solution
# ...

# %%
## rename the columns after merging to the appropriate names for category and title
apps_and_reviews_with_categories.rename(columns = {'title_x': 'title', 'title_y': 'category'}, inplace = True)

# %%
apps_and_reviews_with_categories.head()
# Out:
#                                  app_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7
# 1  afbe525f-d512-4951-8edc-582df3ce6aa7
# 2  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 3  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 4  9594ccfa-9ef9-42a2-823c-e270489bcb88
#
#                                            url  \
# 0  https://apps.shopify.com/jewelexchange_feed
# 1  https://apps.shopify.com/jewelexchange_feed
# 2           https://apps.shopify.com/cocon-app
# 3           https://apps.shopify.com/cocon-app
# 4           https://apps.shopify.com/cocon-app
#
#                             title        developer  \
# 0  JewelExchange Product Feed API  Avalon Solution
# 1  JewelExchange Product Feed API  Avalon Solution
# 2           COCON ‑ Emails, Popup         COCON SA
# 3           COCON ‑ Emails, Popup         COCON SA
# 4           COCON ‑ Emails, Popup         COCON SA
#
#                                       developer_link  \
# 0  https://apps.shopify.com/partners/avalon-solution
# ...

# %%
reviews_in_category = (apps_and_reviews_with_categories.groupby(['category', 'title'], as_index=False)['rating_x'].mean())\
    .dropna(subset=['rating_x'])\
    .groupby(['category'], as_index=False)\
    .mean()\
    .sort_values('rating_x', ascending=True)
reviews_in_category[['mean_rating']] = reviews_in_category[['rating_x']]
reviews_in_category = reviews_in_category.drop(columns=['rating_x'])

plotly.offline.iplot({
    'data': [go.Bar(
        name='Rating',
        x=reviews_in_category['mean_rating'],
        y=reviews_in_category['category'],
        orientation = 'h'
    )],
    'layout': go.Layout(title='Average rating per category', margin=go.layout.Margin(l=250))
})

# %% [markdown]
# ### Customers are least satisfied with Shipping and Delivery apps and most satisfied with Conversion and Merchandising as well as Store Design related Apps.
# ### Correspond to bigger picture of what the execs would get out of this fact!
# Executives are interested in prescrptive analytics as much as descriptive analytics - steps to take to effect such outcomes.
# provide some preseciptive approach by giving some recommendations

# %%
each_rating_count_in_category = pd.DataFrame({
    'category': apps_and_reviews_with_categories['category'].unique(),
    'r_count': [
        apps_and_reviews_with_categories.loc[apps_and_reviews_with_categories['category'] == cat].shape[0]
        for cat in apps_and_reviews_with_categories['category'].unique()],
    'r_1_count': [
        apps_and_reviews_with_categories.loc[(apps_and_reviews_with_categories['rating_y'] == 1.0) & (apps_and_reviews_with_categories['category'] == cat)].shape[0]
        for cat in apps_and_reviews_with_categories['category'].unique()],
    'r_2_count': [
        apps_and_reviews_with_categories.loc[(apps_and_reviews_with_categories['rating_y'] == 2.0) & (apps_and_reviews_with_categories['category'] == cat)].shape[0]
        for cat in apps_and_reviews_with_categories['category'].unique()],
    'r_3_count': [
        apps_and_reviews_with_categories.loc[(apps_and_reviews_with_categories['rating_y'] == 3.0) & (apps_and_reviews_with_categories['category'] == cat)].shape[0]
        for cat in apps_and_reviews_with_categories['category'].unique()],
    'r_4_count': [
        apps_and_reviews_with_categories.loc[(apps_and_reviews_with_categories['rating_y'] == 4.0) & (apps_and_reviews_with_categories['category'] == cat)].shape[0]
        for cat in apps_and_reviews_with_categories['category'].unique()],
    'r_5_count': [
        apps_and_reviews_with_categories.loc[(apps_and_reviews_with_categories['rating_y'] == 5.0) & (apps_and_reviews_with_categories['category'] == cat)].shape[0]
        for cat in apps_and_reviews_with_categories['category'].unique()],
})
each_rating_count_in_category = each_rating_count_in_category.loc[each_rating_count_in_category.category.notna()]

groups = ['r_1_count', 'r_2_count', 'r_3_count', 'r_4_count', 'r_5_count']
traces = []
x_axis_lables = ['Share of 1 star ratings', 'Share of 2 star ratings', 'Share of 3 star ratings', 'Share of 4 star ratings', 'Share of 5 star ratings']

for idx, row in each_rating_count_in_category.iterrows():
    traces.append(go.Bar(
        x=x_axis_lables,
        y=list((row[groups] / row['r_count'])),
        name=row['category']
    ))

layout = go.Layout(
    title='Share of reviews per rating per category',
    yaxis = dict(
        tickformat='.2%'
    )
)

plotly.offline.iplot(go.Figure(data=traces, layout=layout))

each_rating_count_in_category
# Out:
#                         category  r_count  r_1_count  r_2_count  r_3_count  \
# 0                      Marketing   269584       7827       2130       5096
# 1               Store management    52840       2321        610        997
# 2                   Store design   256711       5373       1827       4826
# 3                     Conversion   297041       6651       2226       5189
# 4                  Merchandising    69247       2493        718        888
# 5                    Fulfillment    38996       1746        427        486
# 6          Shipping and delivery    25117       1450        359        459
# 7               Customer service    77630       2370        686       1279
# 8  Sourcing and selling products    77023       5055       1072       1509
#
#    r_4_count  r_5_count
# 0      21340     232762
# 1       3546      45067
# 2      20805     223454
# 3      22445     260115
# 4       3463      61450
# 5       1596      34323
# 6       1384      21131
# ...

# %% [markdown]
# ### Apps with categories in Marketing, Conversion and Store Design leads the pack in ratings counts of 4 and above. complementing.. adds please

# %%
apps_per_category = apps_with_categories\
    .groupby(['title']) \
    .size() \
    .reset_index(name='apps_count') \
    .sort_values('apps_count', ascending=False)

plotly.offline.iplot({
    'data': [go.Pie(labels=apps_per_category['title'], values=apps_per_category['apps_count'])],
    'layout': go.Layout(title='Apps per category')
})

limit = 20
plotly.offline.iplot({
    'data': [go.Bar(
        name='Reviews',
        x=apps_per_category.head(limit)['title'],
        y=apps_per_category.head(limit)['apps_count']
    )],
    'layout': go.Layout(title='Apps ordered by number of category', margin=go.layout.Margin(b=100))
})

# %%
apps_and_reviews_grouped_by_app_title = apps_and_reviews \
    .groupby(['title']) \
    .size() \
    .reset_index(name='reviews') \
    .sort_values('reviews', ascending=False)

limit = 30
plotly.offline.iplot({
    'data': [go.Bar(
        name='Reviews',
        x=apps_and_reviews_grouped_by_app_title.head(limit)['title'],
        y=apps_and_reviews_grouped_by_app_title.head(limit)['reviews']
    )],
    'layout': go.Layout(title='Apps ordered by number of reviews', margin=go.layout.Margin(b=50))
})

# %%
apps_per_price = pricing_plans\
    .groupby(['price']) \
    .size() \
    .reset_index(name='apps_count') \
    .sort_values('apps_count', ascending=False)

limit = 30
plotly.offline.iplot({
    'data': [go.Bar(
        name='price',
        x=apps_per_price.head(limit)['price'],
        y=apps_per_price.head(limit)['apps_count']
    )],
    'layout': go.Layout(title='Apps ordered by price', margin=go.layout.Margin(b=100))
})
plotly.offline.iplot({
    'data': [go.Pie(labels=apps_per_price['price'], values=apps_per_price['apps_count'])],
    'layout': go.Layout(title='Apps per price category')
})

# %% [markdown]
# ### Observations:
# #### - top price categories for all apps are:
# - Free (14.8%),
#
# - Free to Install (9.03%),
#
# - $9.99/month (4.88%),
#
# - $4.99/month (3.53%)
#
# => make up about 32% of all apps pricing.
#
# pricing does not make apps popular on its on, ROI is hard to measure.

# %%
pricing_plans.title.unique()
# Out:
# array([nan, 'Free plan', 'Up to 500 contacts', ..., 'UNI', 'Prime Plan',
#        'For Advanced'], dtype=object)

# %%
apps_with_pricing_plans = pd.merge(apps, pricing_plans, how='right', left_on='app_id', right_on='app_id')

# %%
apps_with_pricing_plans.head()
# Out:
#                                  app_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7
# 1  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 2  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 3  cd229797-5798-4465-a313-2e27ce44e01d
# 4  6e07c6c8-8617-43d2-9a88-bafcbfe82f7f
#
#                                            url  \
# 0  https://apps.shopify.com/jewelexchange_feed
# 1           https://apps.shopify.com/cocon-app
# 2           https://apps.shopify.com/cocon-app
# 3            https://apps.shopify.com/quantify
# 4        https://apps.shopify.com/orderlyprint
#
#                           title_x           developer  \
# 0  JewelExchange Product Feed API     Avalon Solution
# 1           COCON ‑ Emails, Popup            COCON SA
# 2           COCON ‑ Emails, Popup            COCON SA
# 3                        Quantify  Akuna Technologies
# 4                    OrderlyPrint    FORSBERG+two ApS
#
#                                       developer_link  \
# ...

# %% [markdown]
# ### Step 4: Understanding the Features
#
#
# Examine the data description below, and determine if any of the features are missing values or need to be coerced to a different data type.
#
#
# ```
# Input variables:
# # app attributes:
# 1 # of reviews
# 2 app
# 3 pricing
# 4 app category
# 5 Ratings

# %%
## rename the columns after merging to the appropriate names for category and title
apps_with_pricing_plans.rename(columns = {'title_x': 'app_title', 'title_y': 'pricing_plan'}, inplace = True)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 8)
sns.countplot(x = 'rating', data =apps_with_pricing_plans)
ax.set_xlabel('rating', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('Ratings Distribution', fontsize=15)
sns.despine()

# %% [markdown]
# #### Most customers who download the app give a rating in the 0s or mostly in the 4-5 range.

# %%
apps_with_pricing_plans[['reviews_count']].plot(kind = 'box', 
                                              figsize = (8,8),
                                              subplots = True, layout = (1,2),
                                              sharex = False, sharey = False,
                                              title='The Distribution of review counts across apps in the Shopify Apps Store')
plt.show()

# %%
print(apps_with_pricing_plans[apps_with_pricing_plans.reviews_count == apps_with_pricing_plans.reviews_count.max()])
# Out:
#                                    app_id                             url  \
# 154  a66f8834-9975-4392-a70b-8e3ef47817fd  https://apps.shopify.com/privy
# 155  a66f8834-9975-4392-a70b-8e3ef47817fd  https://apps.shopify.com/privy
# 156  a66f8834-9975-4392-a70b-8e3ef47817fd  https://apps.shopify.com/privy
# 157  a66f8834-9975-4392-a70b-8e3ef47817fd  https://apps.shopify.com/privy
#
#                          app_title developer  \
# 154  Privy ‑ Pop Ups, Email, & SMS     Privy
# 155  Privy ‑ Pop Ups, Email, & SMS     Privy
# 156  Privy ‑ Pop Ups, Email, & SMS     Privy
# 157  Privy ‑ Pop Ups, Email, & SMS     Privy
#
#                               developer_link  \
# 154  https://apps.shopify.com/partners/privy
# 155  https://apps.shopify.com/partners/privy
# 156  https://apps.shopify.com/partners/privy
# 157  https://apps.shopify.com/partners/privy
#
#                                                   icon  rating  reviews_count  \
# ...

# %% [markdown]
# #### Apps typically received reviews totalling betwen 0 and 5000 with the most popular app being an outlier at 24780 reviews with the highest rating of 4.6 across its revies received.
# Objective of the project emphasized at the start.
# #### More importantly - it offereed the widest variety of price plans that includes free, Starter and Growth as well as Conversion Only price plans.
# #### Therefore the app- Privy ‑ Pop Ups, Email, & SMS has the most popular and sought after app.

# %%
# distribution of counts across categories of apps
fig, ax = plt.subplots()
fig.set_size_inches(30, 18)
sns.countplot(x = 'category', data = apps_and_reviews_with_categories)
ax.set_xlabel('category', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('review counts Distribution', fontsize=15)
ax.tick_params(labelsize=15)
sns.despine()

# %%
apps.hist(bins=20, figsize=(14,10))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,9))
sns.heatmap(apps_and_reviews_with_categories.corr(), vmin=-1, vmax=1, cmap=sns.diverging_palette(20, 220, as_cmap=True), annot=True, linewidths=.5)
plt.show()

# %% [markdown]
# ### Note: there is a correlation between developer rating y and app rating x

# %% [markdown]
# ### Step 5: Understanding the Task
#
# After examining the description and data, your goal now is to clearly state the *Business Objective* of the task.  State the objective below.

# %% [markdown]
# #### Business Objective of the task:
# #### -  find a model that can explain success of the product/app.
# ####  Such model can increase campaign efficiency by :
# ##### -- identifying the main characteristics that affect success,
# ##### -- helping in a better management of the available resources
# ##### -- and selection of a high quality
# ##### -- and affordable set of potential buying customers.

# %%
apps_with_pricing_plans.head()
# Out:
#                                  app_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7
# 1  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 2  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 3  cd229797-5798-4465-a313-2e27ce44e01d
# 4  6e07c6c8-8617-43d2-9a88-bafcbfe82f7f
#
#                                            url  \
# 0  https://apps.shopify.com/jewelexchange_feed
# 1           https://apps.shopify.com/cocon-app
# 2           https://apps.shopify.com/cocon-app
# 3            https://apps.shopify.com/quantify
# 4        https://apps.shopify.com/orderlyprint
#
#                         app_title           developer  \
# 0  JewelExchange Product Feed API     Avalon Solution
# 1           COCON ‑ Emails, Popup            COCON SA
# 2           COCON ‑ Emails, Popup            COCON SA
# 3                        Quantify  Akuna Technologies
# 4                    OrderlyPrint    FORSBERG+two ApS
#
#                                       developer_link  \
# ...

# %%
apps_with_categories.head()
# Out:
#                                  app_id                       category_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7  c769c2bd15500dd906102d9be97fdceb
# 1  9594ccfa-9ef9-42a2-823c-e270489bcb88  c769c2bd15500dd906102d9be97fdceb
# 2  8ff58c99-e85c-44cd-ad13-7df88fbab704  c769c2bd15500dd906102d9be97fdceb
# 3  0bf899ad-728f-4695-8dd5-cd510a27a4b2  c769c2bd15500dd906102d9be97fdceb
# 4  477982de-97d2-4454-a552-b42bd9b5ccbe  c769c2bd15500dd906102d9be97fdceb
#
#        title
# 0  Marketing
# 1  Marketing
# 2  Marketing
# 3  Marketing
# 4  Marketing

# %%
## rename the columns after merging to the appropriate names for category and title
apps_with_categories.rename(columns = {'title': 'category'}, inplace = True)

# %%
apps_with_categories.head()
# Out:
#                                  app_id                       category_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7  c769c2bd15500dd906102d9be97fdceb
# 1  9594ccfa-9ef9-42a2-823c-e270489bcb88  c769c2bd15500dd906102d9be97fdceb
# 2  8ff58c99-e85c-44cd-ad13-7df88fbab704  c769c2bd15500dd906102d9be97fdceb
# 3  0bf899ad-728f-4695-8dd5-cd510a27a4b2  c769c2bd15500dd906102d9be97fdceb
# 4  477982de-97d2-4454-a552-b42bd9b5ccbe  c769c2bd15500dd906102d9be97fdceb
#
#     category
# 0  Marketing
# 1  Marketing
# 2  Marketing
# 3  Marketing
# 4  Marketing

# %%
apps_with_categories = pd.merge(apps_with_pricing_plans, apps_with_categories, how='left', left_on='app_id', right_on='app_id')

# %%
apps_with_categories.head()
# Out:
#                                  app_id  \
# 0  afbe525f-d512-4951-8edc-582df3ce6aa7
# 1  afbe525f-d512-4951-8edc-582df3ce6aa7
# 2  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 3  9594ccfa-9ef9-42a2-823c-e270489bcb88
# 4  9594ccfa-9ef9-42a2-823c-e270489bcb88
#
#                                            url  \
# 0  https://apps.shopify.com/jewelexchange_feed
# 1  https://apps.shopify.com/jewelexchange_feed
# 2           https://apps.shopify.com/cocon-app
# 3           https://apps.shopify.com/cocon-app
# 4           https://apps.shopify.com/cocon-app
#
#                         app_title        developer  \
# 0  JewelExchange Product Feed API  Avalon Solution
# 1  JewelExchange Product Feed API  Avalon Solution
# 2           COCON ‑ Emails, Popup         COCON SA
# 3           COCON ‑ Emails, Popup         COCON SA
# 4           COCON ‑ Emails, Popup         COCON SA
#
#                                       developer_link  \
# 0  https://apps.shopify.com/partners/avalon-solution
# ...

# %%
apps_with_categories.shape
# Out:
# (17618, 18)

# %%
missing_values = apps_with_categories.isna().mean().round(4) * 100

# %%
missing_values
# Out:
# app_id              0.00
# url                 0.00
# app_title           0.00
# developer           0.00
# developer_link      0.00
# icon                0.00
# rating              0.00
# reviews_count       0.00
# description_raw     0.00
# description         0.00
# tagline             0.00
# pricing_hint        0.00
# lastmod             0.00
# id                  0.00
# pricing_plan       16.94
# price               0.00
# category_id         0.00
# category            0.00
# dtype: float64

# %%
apps_with_categories['pricing_plan'].isnull().sum()
# Out:
# 2985

# %%
apps_with_categories.isnull().sum().sum()
# Out:
# 2985

# %%
# Drop rows that has NaN values on selected columns
apps_with_categories=apps_with_categories.dropna(subset=['pricing_plan'])

# %%
missing_values = apps_with_categories.isna().mean().round(4) * 100

# %%
missing_values
# Out:
# app_id             0.0
# url                0.0
# app_title          0.0
# developer          0.0
# developer_link     0.0
# icon               0.0
# rating             0.0
# reviews_count      0.0
# description_raw    0.0
# description        0.0
# tagline            0.0
# pricing_hint       0.0
# lastmod            0.0
# id                 0.0
# pricing_plan       0.0
# price              0.0
# category_id        0.0
# category           0.0
# dtype: float64

# %%
apps_with_categories.shape
# Out:
# (14633, 18)

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %% [markdown]
# ### Developing an understand what people in reviews are complaining about sieves out Poor quality app which might be an opportunity for the new app that solves the same problem better and allows the Shopify management to better maxmize revenue and lower cost due to attrition of customers frustrated with the apps that was paid but not helping with sales and productivity.

# %%
reviews_with_low_ratings = pd.DataFrame()
for category in apps_and_reviews_with_categories['category'].dropna().unique():
    reviews_in_category = apps_and_reviews_with_categories[apps_and_reviews_with_categories['category'] == category]
    reviews_with_rating_lower_than_app_rating = reviews_in_category[(reviews_in_category['rating_y'] < reviews_in_category['rating_x']) & \
                                                        (reviews_in_category['reviews_count'] > 0)]
    reviews_with_low_ratings = pd.concat([reviews_with_low_ratings, reviews_with_rating_lower_than_app_rating])
reviews_with_low_ratings.head()
# Out:
#                                    app_id                               url  \
# 359  8ff58c99-e85c-44cd-ad13-7df88fbab704  https://apps.shopify.com/smsbump
# 363  8ff58c99-e85c-44cd-ad13-7df88fbab704  https://apps.shopify.com/smsbump
# 429  8ff58c99-e85c-44cd-ad13-7df88fbab704  https://apps.shopify.com/smsbump
# 439  8ff58c99-e85c-44cd-ad13-7df88fbab704  https://apps.shopify.com/smsbump
# 467  8ff58c99-e85c-44cd-ad13-7df88fbab704  https://apps.shopify.com/smsbump
#
#                               title    developer  \
# 359  SMSBump SMS Marketing by Yotpo  SMSBump Ltd
# 363  SMSBump SMS Marketing by Yotpo  SMSBump Ltd
# 429  SMSBump SMS Marketing by Yotpo  SMSBump Ltd
# 439  SMSBump SMS Marketing by Yotpo  SMSBump Ltd
# 467  SMSBump SMS Marketing by Yotpo  SMSBump Ltd
#
#                                    developer_link  \
# 359  https://apps.shopify.com/partners/isenselabs
# 363  https://apps.shopify.com/partners/isenselabs
# 429  https://apps.shopify.com/partners/isenselabs
# ...

# %% [markdown]
# #### You can see the word with the use of Word  combinations that appears on the reviews with low rating. Users complain about those things so they can be used as a proxy to 'what app fail to deliver'.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

reviews_with_low_ratings = reviews_with_low_ratings.dropna(subset=['body'])
reviews_with_low_ratings['negative_prob'] = reviews_with_low_ratings['body'].apply(lambda body: analyser.polarity_scores(body)["neg"])
negative_reviews_with_low_rating = reviews_with_low_ratings[reviews_with_low_ratings['negative_prob'] >= 0.5]

category_id_df = negative_reviews_with_low_rating[['category', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'category']].values)

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, 
                        min_df=3, 
                        norm='l2',
                        ngram_range=(2, 5), 
                        stop_words='english')

features = tfidf.fit_transform(negative_reviews_with_low_rating['body']).toarray()
labels = negative_reviews_with_low_rating['category_id']

# %% [markdown]
# ![image.png](attachment:56fdd0d2-b1a0-4b5e-b8bd-61c701354130.png)
#
# ### Reference: https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html

# %%
N = 15
fig = make_subplots(rows=4, cols=2, 
                          shared_yaxes=False, shared_xaxes=False,
                          horizontal_spacing=0.3, print_grid=False, 
                          subplot_titles=["'{0}' term scores".format(entry[0]) for entry in category_to_id.items()])

charts = []

# %% [markdown]
# #### Compute chi-squared stats between each non-negative feature and class.
#
# #### This score can be used to select the n_features features with the highest values for the test chi-squared statistic from X, which must contain only non-negative features such as booleans or frequencies (e.g., term counts in document classification), relative to the classes.
#
# #### chi-square test measures dependence between stochastic variables, so using this function “weeds out” the features that are the most likely to be independent of class and therefore irrelevant for classification.

# %%
for category, category_id in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])    
    feature_names = np.array(tfidf.get_feature_names())[indices]
    scores = features_chi2[0][indices]

    category_significant_terms = pd.DataFrame({'term': feature_names, 'score': scores})\
        .sort_values('score', ascending=True)\
        .head(N)

    if category_significant_terms.shape[0] == 0:
        next

    bar_chart = go.Bar(
        name=category, 
        x=category_significant_terms['score'], 
        y=category_significant_terms['term'], 
        orientation='h'
    )
    charts.append(bar_chart)

# %%
for number, chart in enumerate(charts):
    row = int(number / 2) + 1
    col = 1 if (number % 2 == 0) else 2
    fig.append_trace(chart, row, col)
    
fig['layout'].update(title='Terms of low rating reviews', 
                     height=3024, width=1000, 
                     margin=go.layout.Margin(l=200, r=100), showlegend=False)
plotly.offline.iplot(fig)

# %% [markdown]
# ### Using Natural Language processing (TfidfVectorizer and SentimentIntensityAnalyzer) clustering techniques and Chi2 feature engineering :
#
#
# ### These charts show that the following words in the reviews fedback on the key areas to reduce customer churn which are the main complaints across all categories.
#
# #### 1. worst user experience, customer support (customer service)
# #### 2. Scam in all areas (app categories)
#
# #### Therefore, the need for Spotify management to focus on budgets / spend on app security, software investment and personnel hiring in the security areas and improve customerservice interactions by closely monitoring app reviews and fraud.

# %% [markdown]
# ### Step 6: Solutions to connect App Users and Developers
# - how can better connect developers to the apps?
# - solution: by identifying the top developers with the most apps offered on the Shopify App store.
# - This helps to show the top developers might not be producing the best apps with the highest reviews.

# %%
limit = 15

apps_per_developer = apps\
    .groupby(['developer']) \
    .size() \
    .reset_index(name='apps_count') \
    .sort_values('apps_count', ascending=False)

plotly.offline.iplot({
    'data': [go.Bar(
            name='Summary rating',
            x=apps_per_developer.head(limit)['developer'],
            y=apps_per_developer.head(limit)['apps_count']
    )],
    'layout': go.Layout(title='Developers ordered by the number of apps', margin=go.layout.Margin(b=100))
})

# %% [markdown]
# #### Note: these are the TOP developers Shopify needs to collaborate more closely with in its ecosystem of apps in order to maxmize customer loyalty through the use of these apps and help promote sales for its sellers on the

# %%
limit = 20

apps_and_reviews_grouped_by_developer = apps_and_reviews \
    .groupby(['developer']) \
    .agg({'rating_y': ['size', 'mean', 'sum']}) \
    .reset_index() \
    .sort_values(('rating_y', 'sum'), ascending=False)


plotly.offline.iplot({
    'data': [go.Bar(
            name='Summary rating',
            x=apps_and_reviews_grouped_by_developer.head(limit)['developer'],
            y=apps_and_reviews_grouped_by_developer.head(limit)[('rating_y', 'sum')]
    ),go.Bar(
            name='Reviews',
            x=apps_and_reviews_grouped_by_developer.head(limit)['developer'],
            y=apps_and_reviews_grouped_by_developer.head(limit)[('rating_y', 'size')]
    ),go.Scatter(
            name='Rating',
            x=apps_and_reviews_grouped_by_developer.head(limit)['developer'],
            y=apps_and_reviews_grouped_by_developer.head(limit)[('rating_y', 'mean')],
            yaxis='y2'
    )],
    'layout': go.Layout(
        title='Developers with the highest summary rating',
        legend=dict(x=1.3, y=1),
        barmode='group',
        yaxis2=dict(
            overlaying='y',
            anchor='x',
            side='right'
        )
    )
})

# %%
limit = 20

apps_and_reviews_grouped_by_developer = apps_and_reviews \
    .groupby(['developer']) \
    .agg({'rating_y': ['size', 'mean', 'sum']}) \
    .reset_index() \
    .sort_values(('rating_y', 'sum'), ascending=True)


plotly.offline.iplot({
    'data': [go.Bar(
            name='Summary rating',
            x=apps_and_reviews_grouped_by_developer.head(limit)['developer'],
            y=apps_and_reviews_grouped_by_developer.head(limit)[('rating_y', 'sum')]
    ),go.Bar(
            name='Reviews',
            x=apps_and_reviews_grouped_by_developer.head(limit)['developer'],
            y=apps_and_reviews_grouped_by_developer.head(limit)[('rating_y', 'size')]
    ),go.Scatter(
            name='Rating',
            x=apps_and_reviews_grouped_by_developer.head(limit)['developer'],
            y=apps_and_reviews_grouped_by_developer.head(limit)[('rating_y', 'mean')],
            yaxis='y2'
    )],
    'layout': go.Layout(
        title='Developers with the lowest summary rating',
        legend=dict(x=1.3, y=1),
        barmode='group',
        yaxis2=dict(
            overlaying='y',
            anchor='x',
            side='right'
        )
    )
})

# %%
apps_and_reviews_grouped_by_developer.head()
# Out:
#                                         developer rating_y
#                                                       size mean  sum
# 0      Hangzhou Mayun Network Technology Co., Ltd        1  NaN  0.0
# 2991                                      RoutiGo        1  NaN  0.0
# 2992                                        Routo        1  NaN  0.0
# 1251                               Eye4fraud Inc.        1  NaN  0.0
# 1250                                  Extreme App        2  NaN  0.0

# %% [markdown]
# ### Shopify Developers that need to start taking note: the ratings have been among the lowest 4s of all the other developers.
# Recommendation:
# #### 1. have close partnerships with its other developers in its ecosystem
# #### Notice that the top app developers in the above app does not have the highest ratings.
# #### For example, ElfSight in the above chart does not have high ratings on its apps.
# ### OR
# ##### 2. simply decide to exit its apps development business and allow its partners to thrive witout competing with them and possibly even outsource to  developer partners the key apps to save personnel costs and focus on fraud prevention and maximizing the merchadising platform and technnology on Shopify.com and its main app.

# %%
X_train.head()

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = preprocessing.MinMaxScaler().fit(features_train)
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

# %% [markdown]
# ### App Leaders in their category!

# %%
apps_with_rating_scores = apps_with_categories[(apps_with_categories['reviews_count'] > 0)].copy()
apps_with_rating_scores['rating_mult_by_reviews'] = apps_with_rating_scores['rating'] * apps_with_rating_scores['reviews_count']

apps_with_highest_score = apps_with_rating_scores\
    .loc[apps_with_rating_scores.groupby(['category'])['rating_mult_by_reviews'].idxmax()]

apps_with_highest_score[['category', 'developer','url','app_title', 'rating', 'reviews_count','price','pricing_plan']]
# Out:
#                             category               developer  \
# 210                       Conversion                   Privy
# 9241                Customer service                    Loox
# 5803                     Fulfillment                  Hextom
# 208                        Marketing                   Privy
# 16358                  Merchandising                 PageFly
# 11299          Shipping and delivery  Automizely & AfterShip
# 199    Sourcing and selling products                   DSers
# 209                     Store design                   Privy
# 8003                Store management                Secomapp
#
#                                                      url  \
# 210                       https://apps.shopify.com/privy
# 9241                       https://apps.shopify.com/loox
# 5803          https://apps.shopify.com/bulk-product-edit
# 208                       https://apps.shopify.com/privy
# 16358                   https://apps.shopify.com/pagefly
# ...

# %% [markdown]
# ### Conclusion
# With the top apps and developers identified to drive the potential revenues and stickiness of the ego systems of apps, the company can now repeat this process at the end of each month to do the following:
#
# ### 1. Maxmize the revenue of looking at promoting the app on the above list more during the month ahead
#
# Privy as the top developer of apps that cater to 3 significant categories of merchant engagement on Shopify definitely deserves a seat at the table with Shopify, its host, and with greater partnership and revenue sharing to develop more apps for its merchants, Shopify can entice its merchants to spend more money on apps which it stands to collect a great deal of revenue both from returned merchants as well as making use of site features to host their merchandise.
#
# ### 2. focus more on the risk area in terms of investing on reducing fraud
# looking at the reviews, Shopify should acknowledge it needs to work closely with its developers on the apps side to close the potential of scammers coming through and destroying ths trust and safety elements that keep its profitablility and market share growing. As such, by deploying the above mentioned process of generating prescriptive and discreptive analytics of its app reviews by category and identifying the app developers that need to be removed from its site or encouraged to improve it practices and app security and integration, Shopify can reduce customer churn and reduce cost to fraudulent activities.
# This would in turn reduce merchant complaints, refunds and revenue loss to criminals and customer churn.
#
# ### 3. improving Shopify's own apps based on the ratings and feedback provided through the repeated process above.
# Shopify being one of the lowest top developers should focus on improving its technology and investing in partnering and learning from its developer base to grow its own apps capabilities to help its partners and merchants deliver and market merchandise more effectively to help grow its revenue.
